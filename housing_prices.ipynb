# %% [markdown]
# # Overview

# %% [markdown]
# This example demonstrates the use `tf.feature_column.crossed_column` on some simulated Atlanta housing price data.
# This spatial data is used primarily so the results can be easily visualized.
#
# These functions are designed primarily for categorical data, not to build interpolation tables.
#
# If you actually want to build smart interpolation tables in TensorFlow you may want to consider [TensorFlow Lattice](https://research.googleblog.com/2017/10/tensorflow-lattice-flexibility.html).

# %% [markdown]
# # Imports

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import subprocess
import tempfile

import tensorflow as tf
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# assert tf.VERSION.split('.') >= ['1','4']

# %%
# %matplotlib inline
mpl.rcParams['figure.figsize'] = 12, 6
mpl.rcParams['image.cmap'] = 'viridis'

# %%
logdir = tempfile.mkdtemp()

# %%
logdir
# Out:
# '/tmp/tmpr5kftog1'

# %% [markdown]
# # Start TensorBoard
# The following command will kill all running TensorBoard processes, and start a new one monitoring to the above logdir.

# %%
subprocess.Popen(['pkill','-f','tensorboard'])
subprocess.Popen(['tensorboard', '--logdir', logdir])

# %% [markdown]
# # Build Synthetic Data

# %%
# Define the grid
min_latitude = 33.641336
max_latitude = 33.887157
delta_latitude = max_latitude-min_latitude

min_longitude = -84.558798
max_longitude = -84.287259
delta_longitude = max_longitude-min_longitude

resolution = 100

# %%
# Use RandomState so the behavior is repeatable. 
R = np.random.RandomState(1)

# %%
# The price data will be a sum of Gaussians, at random locations.
n_centers = 20
centers = R.rand(n_centers, 2)  # shape: (centers, dimensions)

# %%
# Each Gaussian has a maximum price contribution, at the center.
# Price_
price_delta = 0.5+2*R.rand(n_centers)

# %%
# Each Gaussian also has a standard-deviation and variance.
std = 0.2*R.rand(n_centers)  # shape: (centers)
var = std**2

# %%
def price(latitude, longitude):
    # Convert latitude, longitude to x,y in [0,1]
    x = (longitude - min_longitude)/delta_longitude
    y = (latitude - min_latitude)/delta_latitude
    
    # Cache the shape, and flatten the inputs.
    shape = x.shape
    assert y.shape == x.shape
    x = x.flatten()
    y = y.flatten()
    
    # Convert x, y examples into an array with shape (examples, dimensions)
    xy = np.array([x,y]).T

    # Calculate the square distance from each example to each center.  
    components2 = (xy[:,None,:] - centers[None,:,:])**2  # shape: (examples, centers, dimensions)
    r2 = components2.sum(axis=2)  # shape: (examples, centers)
    
    # Calculate the z**2 for each example from each center.
    z2 = r2/var[None,:]
    price = (np.exp(-z2)*price_delta).sum(1)  # shape: (examples,)
    
    # Restore the original shape.
    return price.reshape(shape)

# %%
# Build the grid. We want `resolution` cells between `min` and `max` on each dimension
# so we need `resolution+1` evenly spaced edges. The centers are at the average of the
# upper and lower edge. 

latitude_edges = np.linspace(min_latitude, max_latitude, resolution+1)
latitude_centers = (latitude_edges[:-1] + latitude_edges[1:])/2

longitude_edges = np.linspace(min_longitude, max_longitude, resolution+1)
longitude_centers = (longitude_edges[:-1] + longitude_edges[1:])/2

latitude_grid, longitude_grid = np.meshgrid(
    latitude_centers,
    longitude_centers)

# %%
# Evaluate the price at each center-point
actual_price_grid = price(latitude_grid, longitude_grid)

price_min = actual_price_grid.min()
price_max = actual_price_grid.max()
price_mean = actual_price_grid.mean()
price_mean
# Out:
# 0.87547872338556831

# %%
def show_price(price):
    plt.imshow(
        price, 
        # The color axis goes from `price_min` to `price_max`.
        vmin=price_min, vmax=price_max,
        # Put the image at the correct latitude and longitude.
        extent=(min_longitude, max_longitude, min_latitude, max_latitude), 
        # Make the image square.
        aspect = 1.0*delta_longitude/delta_latitude)

# %%
show_price(actual_price_grid)

# %% [markdown]
# # Build Datasets

# %%
# For test data we will use the grid centers.
test_features = {'latitude':latitude_grid.flatten(), 'longitude':longitude_grid.flatten()}
test_ds = tf.data.Dataset.from_tensor_slices((test_features, 
                                           actual_price_grid.flatten()))
test_ds = test_ds.cache().batch(512).prefetch(1)

# For training data we will use a set of random points.
train_latitude = min_latitude + np.random.rand(50000)*delta_latitude
train_longitude = min_longitude + np.random.rand(50000)*delta_longitude
train_price = price(train_latitude, train_longitude)

train_features = {'latitude':train_latitude, 'longitude':train_longitude}
train_ds = tf.data.Dataset.from_tensor_slices((train_features, train_price))
train_ds = train_ds.cache().repeat().shuffle(100000).batch(512).prefetch(1)

# A shortcut to build an `input_fn` from a `Dataset`
def in_fn(ds):
    return lambda : ds.make_one_shot_iterator().get_next()

# %% [markdown]
# # Generate a plot from an Estimator

# %%
def plot_est(est, ds = test_ds):
    # Create two plot axes
    actual, predicted = plt.subplot(1,2,1), plt.subplot(1,2,2)

    # Plot the actual price.
    plt.sca(actual)
    show_price(actual_price_grid.reshape(resolution, resolution))
    
    # Generate predictions over the grid from the estimator.
    pred =  est.predict(in_fn(ds))
    # Convert them to a numpy array.
    pred = np.fromiter((item['predictions'] for item in pred), np.float32)
    # Plot the predictions on the secodn axis.
    plt.sca(predicted)
    show_price(pred.reshape(resolution, resolution))

# %% [markdown]
# # Using `numeric_column` with DNNRegressor
# Important: Pure categorical data doesn't the spatial relationships that make this example possible. Embeddings are a way your model can learn spatial relationships.

# %%
# Use `normalizer_fn` so that the model only sees values in [0, 1]
norm_latitude = lambda latitude:(latitude-min_latitude)/delta_latitude - 0.5
norm_longitude = lambda longitude:(longitude-min_longitude)/delta_longitude - 0.5

fc = [tf.feature_column.numeric_column('latitude', normalizer_fn = norm_latitude), 
      tf.feature_column.numeric_column('longitude', normalizer_fn = norm_longitude)]

# Build and train the Estimator
est = tf.estimator.DNNRegressor(
    hidden_units=[100,100], 
    feature_columns=fc, 
    model_dir = os.path.join(logdir,'DNN'))

est.train(in_fn(train_ds), steps = 5000)
est.evaluate(in_fn(test_ds))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpr5kftog1/DNN', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75490c0780>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /home/yqstar/anaconda3/envs/tf13_env/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754995abe0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754995abe0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754995abe0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754995abe0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754995abe0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754995abe0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/yqstar/anaconda3/envs/tf13_env/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpr5kftog1/DNN/model.ckpt.
# INFO:tensorflow:loss = 621.283, step = 1
# INFO:tensorflow:global_step/sec: 495.732
# INFO:tensorflow:loss = 119.092, step = 101 (0.203 sec)
# INFO:tensorflow:global_step/sec: 607.435
# INFO:tensorflow:loss = 113.552, step = 201 (0.164 sec)
# INFO:tensorflow:global_step/sec: 609.503
# INFO:tensorflow:loss = 77.8134, step = 301 (0.164 sec)
# INFO:tensorflow:global_step/sec: 609.314
# INFO:tensorflow:loss = 95.2049, step = 401 (0.164 sec)
# INFO:tensorflow:loss = 14.3244, step = 3201 (0.158 sec)
# INFO:tensorflow:global_step/sec: 636.316
# INFO:tensorflow:loss = 6.89895, step = 3301 (0.157 sec)
# INFO:tensorflow:global_step/sec: 595.73
# INFO:tensorflow:loss = 12.3217, step = 3401 (0.168 sec)
# INFO:tensorflow:global_step/sec: 632.132
# INFO:tensorflow:loss = 12.5617, step = 3501 (0.158 sec)
# INFO:tensorflow:global_step/sec: 624.511
# INFO:tensorflow:loss = 8.15473, step = 3601 (0.160 sec)
# INFO:tensorflow:global_step/sec: 602.842
# INFO:tensorflow:loss = 7.7479, step = 3701 (0.166 sec)
# INFO:tensorflow:global_step/sec: 626.275
# INFO:tensorflow:loss = 12.5483, step = 3801 (0.160 sec)
# INFO:tensorflow:global_step/sec: 633.59
# INFO:tensorflow:loss = 11.216, step = 3901 (0.158 sec)
# INFO:tensorflow:global_step/sec: 581.511
# INFO:tensorflow:loss = 10.468, step = 4001 (0.171 sec)
# INFO:tensorflow:global_step/sec: 628.961
# INFO:tensorflow:loss = 5.23312, step = 4101 (0.159 sec)
# INFO:tensorflow:global_step/sec: 641.597
# INFO:tensorflow:loss = 11.3231, step = 4201 (0.156 sec)
# INFO:tensorflow:global_step/sec: 598.712
# INFO:tensorflow:loss = 8.07911, step = 4301 (0.167 sec)
# INFO:tensorflow:global_step/sec: 637.706
# INFO:tensorflow:loss = 12.5252, step = 4401 (0.157 sec)
# INFO:tensorflow:global_step/sec: 638.28
# INFO:tensorflow:loss = 11.172, step = 4501 (0.156 sec)
# INFO:tensorflow:global_step/sec: 617.691
# INFO:tensorflow:loss = 10.5362, step = 4601 (0.162 sec)
# INFO:tensorflow:global_step/sec: 554.347
# INFO:tensorflow:loss = 8.28267, step = 4701 (0.180 sec)
# INFO:tensorflow:global_step/sec: 622.7
# INFO:tensorflow:loss = 7.07033, step = 4801 (0.161 sec)
# INFO:tensorflow:global_step/sec: 606.099
# INFO:tensorflow:loss = 12.2941, step = 4901 (0.165 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpr5kftog1/DNN/model.ckpt.
# INFO:tensorflow:Loss for final step: 8.28055.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75ca7a2400>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75ca7a2400>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75ca7a2400>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75ca7a2400>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-05-03T07:28:56Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /home/yqstar/anaconda3/envs/tf13_env/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /tmp/tmpr5kftog1/DNN/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2023-05-03-07:28:56
# INFO:tensorflow:Saving dict for global step 5000: average_loss = 0.0150364, global_step = 5000, label/mean = 0.875479, loss = 7.51822, prediction/mean = 0.892624
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpr5kftog1/DNN/model.ckpt-5000
# {'average_loss': 0.01503644,
#  'global_step': 5000,
#  'label/mean': 0.87547863,
#  'loss': 7.5182199,
#  'prediction/mean': 0.8926242}

# %%
plot_est(est)
# Out:
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75287d8b00>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75287d8b00>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75287d8b00>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75287d8b00>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpr5kftog1/DNN/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# # Using `bucketized_column`

# %%
# Bucketize the latitude and longitude usig the `edges`
latitude_bucket_fc = tf.feature_column.bucketized_column(
    tf.feature_column.numeric_column('latitude'), 
    list(latitude_edges))

longitude_bucket_fc = tf.feature_column.bucketized_column(
    tf.feature_column.numeric_column('longitude'),
    list(longitude_edges))

fc = [
    latitude_bucket_fc,
    longitude_bucket_fc]

# Build and train the Estimator.
est = tf.estimator.LinearRegressor(fc, model_dir = os.path.join(logdir,'separable'))
est.train(in_fn(train_ds), steps = 5000)
est.evaluate(in_fn(test_ds))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tm
(0.084 sec)
# INFO:tensorflow:global_step/sec: 1193.48
# INFO:tensorflow:loss = 111.087, step = 4301 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1180.99
# INFO:tensorflow:loss = 124.113, step = 4401 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1201.21
# INFO:tensorflow:loss = 128.481, step = 4501 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1177.07
# INFO:tensorflow:loss = 127.685, step = 4601 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1224.06
# INFO:tensorflow:loss = 124.445, step = 4701 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1139.31
# INFO:tensorflow:loss = 145.122, step = 4801 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1131.74
# INFO:tensorflow:loss = 145.647, step = 4901 (0.088 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpr5kftog1/separable/model.ckpt.
# INFO:tensorflow:Loss for final step: 150.834.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75490c0518>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75490c0518>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75490c0518>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75490c0518>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-05-03T07:29:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpr5kftog1/separable/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2023-05-03-07:29:02
# INFO:tensorflow:Saving dict for global step 5000: average_loss = 0.249552, global_step = 5000, label/mean = 0.875479, loss = 124.776, prediction/mean = 0.872138
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpr5kftog1/separable/model.ckpt-5000
# {'average_loss': 0.24955153,
#  'global_step': 5000,
#  'label/mean': 0.87547863,
#  'loss': 124.77577,
#  'prediction/mean': 0.87213778}

# %%
plot_est(est)
# Out:
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7506f4f2e8>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7506f4f2e8>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7506f4f2e8>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7506f4f2e8>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpr5kftog1/separable/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# # Using `crossed_column` on its own.
# The single-cell "holes" in the figure are caused by cells which do not contain examples.

# %%
# Cross the bucketized columns, using 5000 hash bins (for an average weight sharing of 2).
crossed_lat_lon_fc = tf.feature_column.crossed_column(
    [latitude_bucket_fc, longitude_bucket_fc], int(5e3))

fc = [crossed_lat_lon_fc]

# Build and train the Estimator.
est = tf.estimator.LinearRegressor(fc, model_dir=os.path.join(logdir, 'crossed'))

est.train(in_fn(train_ds), steps = 5000)
est.evaluate(in_fn(test_ds))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpr5kftog1/crossed', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75499b2320>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2a58>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2a58>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2a58>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2a58>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2a58>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2a58>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpr5kftog1/crossed/model.ckpt.
# INFO:tensorflow:loss = 664.784, step = 1
# INFO:tensorflow:global_step/sec: 671.35
# INFO:tensorflow:loss = 170.19, step = 101 (0.150 sec)
# INFO:tensorflow:global_step/sec: 926.11
# INFO:tensorflow:loss = 143.199, step = 201 (0.108 sec)
# INFO:tensorflow:global_step/sec: 915.08
# INFO:tensorflow:loss = 161.205, step = 301 (0.109 sec)
# INFO:tensorflow:global_step/sec: 906.745
# INFO:tensorflow:loss = 151.923, step = 401 (0.110 sec)
# INFO:tensorflow:global_step/sec: 933.293
# INFO:tensorflow:loss = 170.29, step = 501 (0.107 sec)
# INFO:tensorflow:global_step/sec: 921.22
# INFO:tensorflow:loss = 142.063, step = 601 (0.109 sec)
# INFO:tensorflow:global_step/sec: 939.067
# INFO:tensorflow:loss = 131.951, step = 701 (0.106 sec)
# INFO:tensorflow:global_step/sec: 945.865
# INFO:tensorflow:loss = 171.237, step = 801 (0.106 sec)
# INFO:tensorflow:global_step/sec: 923.817
# INFO:tensorflow:loss = 145.542, step = 901 (0.108 sec)
# INFO:tensorflow:global_step/sec: 909.025
# INFO:tensorflow:loss = 150.013, step = 1001 (0.110 sec)
# INFO:tensorflow:global_step/sec: 936.896
# INFO:tensorflow:loss = 164.828, step = 1101 (0.107 sec)
# INFO:tensorflow:loss = 153.367, step = 3901 (0.107 sec)
# INFO:tensorflow:global_step/sec: 927.117
# INFO:tensorflow:loss = 151.008, step = 4001 (0.108 sec)
# INFO:tensorflow:global_step/sec: 925.752
# INFO:tensorflow:loss = 134.708, step = 4101 (0.108 sec)
# INFO:tensorflow:global_step/sec: 944.852
# INFO:tensorflow:loss = 126.418, step = 4201 (0.106 sec)
# INFO:tensorflow:global_step/sec: 935.861
# INFO:tensorflow:loss = 153.227, step = 4301 (0.107 sec)
# INFO:tensorflow:global_step/sec: 897.83
# INFO:tensorflow:loss = 129.681, step = 4401 (0.111 sec)
# INFO:tensorflow:global_step/sec: 916.207
# INFO:tensorflow:loss = 147.018, step = 4501 (0.109 sec)
# INFO:tensorflow:global_step/sec: 941.254
# INFO:tensorflow:loss = 147.103, step = 4601 (0.106 sec)
# INFO:tensorflow:global_step/sec: 935.012
# INFO:tensorflow:loss = 166.782, step = 4701 (0.107 sec)
# INFO:tensorflow:global_step/sec: 935.984
# INFO:tensorflow:loss = 142.413, step = 4801 (0.107 sec)
# INFO:tensorflow:global_step/sec: 938.995
# INFO:tensorflow:loss = 156.527, step = 4901 (0.107 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpr5kftog1/crossed/model.ckpt.
# INFO:tensorflow:Loss for final step: 157.744.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2358>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2358>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2358>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499b2358>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-05-03T07:29:09Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpr5kftog1/crossed/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2023-05-03-07:29:09
# INFO:tensorflow:Saving dict for global step 5000: average_loss = 0.328021, global_step = 5000, label/mean = 0.875479, loss = 164.01, prediction/mean = 0.873904
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpr5kftog1/crossed/model.ckpt-5000
# {'average_loss': 0.32802063,
#  'global_step': 5000,
#  'label/mean': 0.87547863,
#  'loss': 164.01031,
#  'prediction/mean': 0.87390393}

# %%
plot_est(est)
# Out:
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f752876d588>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f752876d588>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f752876d588>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f752876d588>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpr5kftog1/crossed/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# # Using raw categories with `crossed_column`
# The model generalizes better if it also has access to the raw categories, outside of the cross.

# %%
fc = [
    latitude_bucket_fc,
    longitude_bucket_fc,
    crossed_lat_lon_fc]

# Build and train the Estimator.
est = tf.estimator.LinearRegressor(fc, model_dir=os.path.join(logdir, 'both'))
est.train(in_fn(train_ds), steps = 5000)
est.evaluate(in_fn(test_ds))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpr5kftog1/both', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75287077b8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7528707908>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7528707908>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7528707908>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7528707908>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7528707908>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f7528707908>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpr5kftog1/both/model.ckpt.
# INFO:tensorflow:loss = 724.895, step = 1
# INFO:tensorflow:global_step/sec: 523.892
# INFO:tensorflow:loss = 74.7485, step = 101 (0.192 sec)
# INFO:tensorflow:global_step/sec: 863.793
# INFO:tensorflow:loss = 65.7692, step = 201 (0.116 sec)
# INFO:tensorflow:global_step/sec: 897.298
# INFO:tensorflow:loss = 77.4338, step = 301 (0.111 sec)
# INFO:tensorflow:global_step/sec: 856.986
# INFO:tensorflow:loss = 70.5064, step = 401 (0.117 sec)
# INFO:tensorflow:global_step/sec: 886.835
# INFO:tensorflow:loss = 81.3553, step = 501 (0.113 sec)
# INFO:tensorflow:global_step/sec: 869.498
# INFO:tensorflow:loss = 65.34, step = 601 (0.115 sec)
# INFO:tensorflow:global_step/sec: 826.26
# INFO:tensorflow:loss = 70.9229, step = 701 (0.121 sec)
# INFO:tensorflow:global_step/sec: 818.639
# INFO:tensorflow:loss = 64.4729, step = 3501 (0.115 sec)
# INFO:tensorflow:global_step/sec: 897.281
# INFO:tensorflow:loss = 69.4432, step = 3601 (0.111 sec)
# INFO:tensorflow:global_step/sec: 863.991
# INFO:tensorflow:loss = 67.9781, step = 3701 (0.116 sec)
# INFO:tensorflow:global_step/sec: 859.048
# INFO:tensorflow:loss = 76.753, step = 3801 (0.116 sec)
# INFO:tensorflow:global_step/sec: 835.835
# INFO:tensorflow:loss = 69.4331, step = 3901 (0.120 sec)
# INFO:tensorflow:global_step/sec: 850.894
# INFO:tensorflow:loss = 67.2015, step = 4001 (0.117 sec)
# INFO:tensorflow:global_step/sec: 860.43
# INFO:tensorflow:loss = 64.75, step = 4101 (0.116 sec)
# INFO:tensorflow:global_step/sec: 796.669
# INFO:tensorflow:loss = 69.6149, step = 4201 (0.125 sec)
# INFO:tensorflow:global_step/sec: 862.658
# INFO:tensorflow:loss = 64.1183, step = 4301 (0.117 sec)
# INFO:tensorflow:global_step/sec: 887.188
# INFO:tensorflow:loss = 61.8465, step = 4401 (0.112 sec)
# INFO:tensorflow:global_step/sec: 863.393
# INFO:tensorflow:loss = 65.8297, step = 4501 (0.116 sec)
# INFO:tensorflow:global_step/sec: 869.118
# INFO:tensorflow:loss = 65.8104, step = 4601 (0.115 sec)
# INFO:tensorflow:global_step/sec: 820.888
# INFO:tensorflow:loss = 74.6189, step = 4701 (0.122 sec)
# INFO:tensorflow:global_step/sec: 876.807
# INFO:tensorflow:loss = 73.9378, step = 4801 (0.114 sec)
# INFO:tensorflow:global_step/sec: 864.265
# INFO:tensorflow:loss = 75.7552, step = 4901 (0.116 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpr5kftog1/both/model.ckpt.
# INFO:tensorflow:Loss for final step: 67.5878.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f755360aef0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f755360aef0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f755360aef0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f755360aef0>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-05-03T07:29:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpr5kftog1/both/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2023-05-03-07:29:18
# INFO:tensorflow:Saving dict for global step 5000: average_loss = 0.148164, global_step = 5000, label/mean = 0.875479, loss = 74.0818, prediction/mean = 0.876406
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpr5kftog1/both/model.ckpt-5000
# {'average_loss': 0.14816366,
#  'global_step': 5000,
#  'label/mean': 0.87547863,
#  'loss': 74.081833,
#  'prediction/mean': 0.87640625}

# %%
plot_est(est)
# Out:
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754cfce0b8>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754cfce0b8>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (?,), longitude: (?,)}, (?,)), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754cfce0b8>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7f754cfce0b8>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7f75499c1668>) the dataset: <DatasetV1Adapter shapes: ({latitude: (), longitude: ()}, ()), types: ({latitude: tf.float64, longitude: tf.float64}, tf.float64)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpr5kftog1/both/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# # Open TensorBoard

# %%
# %%html
# <iframe width="900" height="800" src="http://0.0.0.0:6006#scalars&_smoothingWeight=0.85" frameborder="0"></iframe>
# Out:
# <iframe width="900" height="800" src="http://0.0.0.0:6006#scalars&_smoothingWeight=0.85" frameborder="0"></iframe>
